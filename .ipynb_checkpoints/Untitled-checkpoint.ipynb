# %%
import numpy as np

import scipy as sp

import pandas as pd

import matplotlib as mpl

import seaborn as sns

# %%
import pandas as pd
question_set = pd.read_csv("C:/Users/rafi/Desktop/New folder/dataset.csv", usecols = ['Questions'], encoding='latin1')
print(question_set)

answer_set = pd.read_csv("C:/Users/rafi/Desktop/New folder/dataset.csv", usecols = ['Answer'], encoding='latin1')
print(answer_set)
# Out:
#                                              Questions
# 0                                  How do I apply?\n\n
# 1                                                  Hi
# 2                                              Hello
# 3                                      Good Morining
# 4                                          Good Noon
# 5                                     Good Afternoon
# 6                                   Thank you so much
# 7                                               Thanks
# 8                                         How are you?
# 9                                                  Bye
# 10                                    Nice to meet you
# 11                                  Semester duretion?
# 12                  How many months in a semester?\n\n
# 13   What criteria do you use for acceptance into y...
# 14                  How much extra curriculum fee?\n\n
# 15                               extra curriculum fee?
# ...

# %%
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.feature_extraction.text import TfidfTransformer

from nltk.corpus import stopwords

import numpy as np

import numpy.linalg as LA

import nltk
nltk.download('stopwords')



train_set = list(question_set['Questions'])

reply_set = list(answer_set['Answer'])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\rafi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
q = int(0)
while(1):
    
    if q==0:
        
        print('Reply: Hello Sir! I am DIUBot to help you.')

    test_set = [input()]    

    if test_set[0]=='No' or test_set[0]=='no':
        
        print('Reply: Thanks you so much. Nice to meet you sir.')
        break
    else:
           
        stopWords = stopwords.words('english')
        vectorizer = CountVectorizer(stop_words = stopWords)
        transformer = TfidfTransformer()
        trainVectorizerArray = vectorizer.fit_transform(train_set).toarray()
        testVectorizerArray = vectorizer.transform(test_set).toarray()
        cx = lambda a, b : round(np.inner(a, b)/(LA.norm(a)*LA.norm(b)), 3)
        count = int(0)
        mx_cosine = float(0.00000)
        for vector in trainVectorizerArray:
            for testV in testVectorizerArray:
                cosine = cx(vector, testV)
            if float(cosine) > mx_cosine :
                in_dex = count
                mx_cosine = cosine
            count = count + 1
        print('Reply: ', reply_set[in_dex])
        print("\nIf you have no more question then please write 'No' or ask the further question.")
        q =+1
# Out:
# Reply: Hello Sir! I am DIUBot to help you.
# No
# Reply: Thanks you so much. Nice to meet you sir.

# %%
#Questionset

"How do I apply?

"
Hi 
Hello  
Good Morining  
Good Noon  
Good Afternoon  
Thank you so much 
Thanks
How are you?
Bye
Nice to meet you
Semester duretion?
"How many months in a semester?

"
"What criteria do you use for acceptance into your programs?

"
"How much extra curriculum fee?

"
extra curriculum fee?
"How do I choose whether to apply to the MS or the PhD program?

"
first semester cost?
first semester credit details?
Total credit of CSE?
"Which semester how amount?

"
"How much I have to pay as admission fee?

"
admission fee
"What is part time job ?

"
"How much I have to pay for admission today?

"
Only admission fees?
"How many semester in CSE?

"
Total semester in CSE 
"How many slots in a semester for paying total semester cost?

"
How to pay smester fees?
"Can I apply for both the MS and the PhD program

"
"How much total Lab Cost?

"
Lab fees?
"Is there any condition for getting free laptop?

"
How I get free laptop?
"Is there any free laptop for each student?

"
"is the graduate application deadline?

"
"How much cost in a semester?

"
"Total cost to complete CSE?

"
Total fees for CSE program?
Total amaount of CSE Day graduation program ?
"How much project fee?

"
project fee?
"Which brand laptop?

"
"Can I take a CSE class if I am not a major?

"
"Does CSE offer a program in Computer Animation?

"
head of CSE ?
Who is the head of CSE department?
Who is   the Pro VC of DIU?
Who is   the VC of DIU?
Who is   the Vice Chancellor of DIU?
Who is the  Chairman of DIU?
Who is the dean of Faculty of Science and Information Technology?
Who is the Associate Dean of FSIT?
Who is the Associate Dean of Faculty of Science and Information Technology?
Who is the dean of FSIT?
